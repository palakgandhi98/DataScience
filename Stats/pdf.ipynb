# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.kdeplot(data=df,x='sepal_length',hue='species')
#data are overlaps more
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='sepal_width',hue='species')
#data are overlapes more
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='petal_length',hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='petal_width',hue='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='petal_width',hue='species')
sns.ecdfplot(data=df,x='petal_width',hue='species')

#below this graph we saying this in range 0.7<petal_width<1.7 --> 95% are versicolor and 10% are verginica and above 1.7< are 90% are verginica
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
import pandas as pd
from google.colab import files
upload=files.upload()

ta = pd.read_csv('titanic.csv')
ta.head()
# Out:
#      <input type="file" id="files-6f70a8b0-29ee-492a-a8d8-fde6c91427e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f70a8b0-29ee-492a-a8d8-fde6c91427e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sns.kdeplot(data=ta, x='age', hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
#2d plot

sns.jointplot(data=df, x='petal_length', y='sepal_length', kind='kde')

# %%
sns.jointplot(data=df, x='petal_length', y='sepal_length', kind='kde', fill=True)

# %%
sns.jointplot(data=df, x='petal_length', y='sepal_length', kind='kde', fill=True, cbar=True)

# %%
sns.jointplot(data=df, x='petal_length', y='sepal_length', kind='kde',thresh=0, levels=100, cmap="mako",fill=True,cbar=True)

# %%
#normaliz --- standard normlize

sns.kdeplot(data=ta, x='age')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
ta['age'].mean()
# Out:
# 29.69911764705882

# %%
ta['age'].std()
# Out:
# 14.526497332334042

# %%
x = (ta['age']-ta['age'].mean())/ta['age'].std()

# %%
sns.kdeplot(x)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
x.mean()
# Out:
# 2.338621049070358e-16

# %%
x.std()
# Out:
# 1.0

# %%
#skewness

ta['age'].skew()
# Out:
# 0.38910778230082704

# %%
x.skew()
# Out:
# 0.389107782300826

# %%
df['petal_width'].skew()
# Out:
# -0.10296674764898116

# %%
#outlier

ta['age'].mean() + 3*ta['age'].std()
# Out:
# 73.27860964406094

# %%
ta['age'].mean() - 3*ta['age'].std()
# Out:
# -13.880374349943303

# %%
ta[ta['age']> 73]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.000        S  First  man
# 851         0       3  male  74.0      0      0   7.775        S  Third  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True
