# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=645dc23a7d825e49853591dd841d1039&language=en-US&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 146.75,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.708,
#    'vote_count': 19117},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
response.json()['total_pages']
# Out:
# 451

# %%
response.json()['total_results']
# Out:
# 9009

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 146.75,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.708,
#   'vote_count': 19117},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
pd.DataFrame(response.json()['results']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              20 non-null     bool
#  1   backdrop_path      20 non-null     object
#  2   genre_ids          20 non-null     object
#  3   id                 20 non-null     int64
#  4   original_language  20 non-null     object
#  5   original_title     20 non-null     object
#  6   overview           20 non-null     object
#  7   popularity         20 non-null     float64
#  8   poster_path        20 non-null     object
#  9   release_date       20 non-null     object
#  10  title              20 non-null     object
#  11  video              20 non-null     bool
#  12  vote_average       20 non-null     float64
#  13  vote_count         20 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 2.0+ KB

# %%
pd.json_normalize(response.json()['results']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              20 non-null     bool
#  1   backdrop_path      20 non-null     object
#  2   genre_ids          20 non-null     object
#  3   id                 20 non-null     int64
#  4   original_language  20 non-null     object
#  5   original_title     20 non-null     object
#  6   overview           20 non-null     object
#  7   popularity         20 non-null     float64
#  8   poster_path        20 non-null     object
#  9   release_date       20 non-null     object
#  10  title              20 non-null     object
#  11  video              20 non-null     bool
#  12  vote_average       20 non-null     float64
#  13  vote_count         20 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 2.0+ KB

# %%
pd.json_normalize(response.json()['results'])[['id','title']]
# Out:
#         id                                          title
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4    19404                    Dilwale Dulhania Le Jayenge
# 5      389                                   12 Angry Men
# 6      129                                  Spirited Away
# 7   496243                                       Parasite
# 8      155                                The Dark Knight
# 9      497                                 The Green Mile
# 10  372058                                     Your Name.
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20 non-null     int64
#  1   title         20 non-null     object
#  2   overview      20 non-null     object
#  3   release_date  20 non-null     object
#  4   popularity    20 non-null     float64
#  5   vote_average  20 non-null     float64
#  6   vote_count    20 non-null     int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.2+ KB

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,452):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=645dc23a7d825e49853591dd841d1039&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# <ipython-input-28-f82ce85ce2ba>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-28-f82ce85ce2ba>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-28-f82ce85ce2ba>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-28-f82ce85ce2ba>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#          id                        title  \
# 0       238                The Godfather
# 1       278     The Shawshank Redemption
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4     19404  Dilwale Dulhania Le Jayenge
# ...     ...                          ...
# 9004  12142            Alone in the Dark
# 9005   5491            Battlefield Earth
# 9006  11059            House of the Dead
# 9007  14164         Dragonball Evolution
# 9008  40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...

# %%
df.shape
# Out:
# (9009, 7)

# %%
df.to_csv('movies.csv')

# %%
import pandas as pd
import json
