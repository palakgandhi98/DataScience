# %%
import requests
import pandas as pd
# Out:
# <ipython-input-23-38b06d79e00b>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-23-38b06d79e00b>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-23-38b06d79e00b>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-23-38b06d79e00b>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)

# %%
response = requests.get('https://api.themoviedb.org/3/tv/popular?api_key=645dc23a7d825e49853591dd841d1039&language=en-US&page={}'.format(i))

# %%
pd.DataFrame(response.json())['results'][0]
# Out:
# {'adult': False,
#  'backdrop_path': '/oOce9hLMVFubjAJliau4kiSNPnW.jpg',
#  'genre_ids': [80, 18],
#  'id': 549,
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_name': 'Law & Order',
#  'overview': "In cases ripped from the headlines, police investigate serious and often deadly crimes, weighing the evidence and questioning the suspects until someone is taken into custody. The district attorney's office then builds a case to convict the perpetrator by proving the person guilty beyond a reasonable doubt. Working together, these expert teams navigate all sides of the complex criminal justice system to make New York a safer place.",
#  'popularity': 5388.629,
#  'poster_path': '/77OPlbsvX3pzoFbyfpcE3GXMCod.jpg',
#  'first_air_date': '1990-09-13',
#  'name': 'Law & Order',
#  'vote_average': 7.4,
#  'vote_count': 486}

# %%
response.json()['total_pages']
# Out:
# 8050

# %%
pd.DataFrame(response.json()['results'])[['id','name','origin_country','overview','popularity','first_air_date','vote_average','vote_count']]
# Out:
#        id                               name origin_country  \
# 0     549                        Law & Order           [US]
# 1    1431     CSI: Crime Scene Investigation           [US]
# 2    2734  Law & Order: Special Victims Unit           [US]
# 3    1419                             Castle           [US]
# 4    4601       Law & Order: Criminal Intent           [US]
# 5    4057                     Criminal Minds           [US]
# 6    1434                         Family Guy           [US]
# 7    5920                      The Mentalist           [US]
# 8    4614                               NCIS           [US]
# 9    1433                      American Dad!           [US]
# 10   1622                       Supernatural           [US]
# 11  94722                         Tagesschau           [DE]
# 12  68913                           Snowfall           [NO]
# 13   1695                               Monk           [US]
# 14   1911                              Bones           [US]
# ...

# %%
df = pd.DataFrame()
df

for i in range(1,8053):
    response = requests.get('https://api.themoviedb.org/3/tv/popular?api_key=645dc23a7d825e49853591dd841d1039&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','name','origin_country','overview','popularity','first_air_date','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# <ipython-input-30-c286094af85c>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-30-c286094af85c>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-30-c286094af85c>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-30-c286094af85c>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.to_csv('TV_Series.csv')
