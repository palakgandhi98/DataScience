# %% [markdown]
# ## Statistics Practical Implementation
# ### Measure Of Central Tendency
#
# 1. Mean
# 2. Median
# 3. Mode

# %%
ages=np.array([23,24,32,45,12,43,67,45,32,56,32,120])

# %%
import numpy as np
print(np.mean(ages))
print(np.median(ages))
# Out:
# 44.25
# 37.5

# %%
np.sum(ages)
# Out:
# 531

# %%
ages.shape
# Out:
# (12,)

# %%
len(ages)
# Out:
# 12

# %%
import statistics
print(statistics.mean(ages))
print(statistics.median(ages))
# Out:
# 44
# 37.5

# %%
import statistics
statistics.mode(ages)
# Out:
# 32

# %%
np.sort(ages)
# Out:
# array([ 12,  23,  24,  32,  32,  32,  43,  45,  45,  56,  67, 120])

# %%
import seaborn as sns
sns.boxplot(ages)
# Out:
# <Axes: >

# %% [markdown]
# ## 5 Number Summary

# %%
import numpy as np
q1,q3=np.percentile(ages,[25,75])

# %%
print(q1,q3)
# Out:
# 30.0 47.75

# %%
## to check outlier[Lower Fence- Higher fence]
IQR=q3-q1
lower_fence=q1-1.5*(IQR)
higher_fence=q3+1.5*(IQR)
print(lower_fence,higher_fence)
# Out:
# 3.375 74.375

# %% [markdown]
# ## Measure Of Dispersion
#
# 1. Variance
# 2. Standard Deviation

# %%
statistics.variance(ages) #/n-1 sample variance
# Out:
# 795

# %%
np.var(ages,axis=0) #/n population variance
# Out:
# 729.0208333333334

# %%
#sample variance
def variance(data):
  n=len(ages)
  ## mean of the data
  mean=sum(data)/n
  ## variance
  deviation=[(x - mean) ** 2 for x in data]
  variance=sum(deviation)/(n-1)
  return variance

# %%
variance(ages)
# Out:
# 795.2954545454545

# %%
#population variance
def variance(data):
  n=len(ages)
  ## mean of the data
  mean=sum(data)/n
  ## variance
  deviation=[(x - mean) ** 2 for x in data]
  variance=sum(deviation)/n
  return variance

# %%
variance(ages)
# Out:
# 729.0208333333334

# %%
#population variance
#dof = degree of freedom
def variance(data,dof=0):
  n=len(ages)
  ## mean of the data
  mean=sum(data)/n
  ## variance
  deviation=[(x - mean) ** 2 for x in data]
  variance=sum(deviation)/(n-dof)
  return variance

# %%
variance(ages,0)
# Out:
# 729.0208333333334

# %%
variance(ages,1)
# Out:
# 795.2954545454545

# %%
variance(ages,dof=1)
# Out:
# 795.2954545454545

# %%
statistics.pvariance(ages) #population variance
# Out:
# 729

# %%
import math
math.sqrt(statistics.pvariance(ages)) #standard deviation
# Out:
# 27.0

# %% [markdown]
# ## Histograms And PDF

# %%
import seaborn as sns
sns.histplot(ages,kde=True)
#exponentail curve are probability density function
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(ages)
# Out:
# <Axes: ylabel='Count'>

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['petal_length'].plot(kind='hist', bins=20, title='petal_length')
# ...

# %%
sns.histplot(df['sepal_length'],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df['petal_length'],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
## create a normal distributed data
s=np.random.normal(0.5,0.2,1000) #mean,sd,length

# %%
s
# Out:
# array([ 0.47991549,  0.71929807,  0.30034317,  0.67136514,  0.48620966,
#         0.2496534 ,  0.49772792,  0.558762  ,  0.01424021,  0.21129737,
#         0.76766069,  0.52307317,  0.46351069,  0.41196221,  0.73309261,
#         0.63786798,  0.58346775,  0.31943557,  0.39752657,  0.51625183,
#         0.61517009,  0.06725406,  0.57335296,  0.90924983,  0.54664206,
#         0.35730433,  0.57331241,  0.45928192,  0.71272436,  0.12030247,
#         0.6214671 ,  0.27272637,  0.58026962,  0.87222246,  0.65013961,
#         0.36009267,  0.41353487,  0.55538551,  0.42773919,  0.6115395 ,
#         0.34157606,  0.48598224,  0.6163786 ,  0.54101823,  0.39341167,
#         0.38194568,  0.58742051,  0.32021505,  0.78089139,  0.06742319,
#         0.32769548,  0.29654391,  0.30076527,  0.64582121,  0.53232728,
#         0.47209626,  0.1899703 ,  0.26550039,  0.48386113,  0.74321064,
#         0.43513982,  0.42076233,  0.56820986,  0.48044043,  0.48454107,
# ...

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Other Distribuiton
# ## Log Normal Distribution,Power Law Distribution

# %%
mu, sigma = 3., 1. # mean and standard deviation
s = np.random.lognormal(mu, sigma, 1000)

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(s),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Check whether Disstribution is Normal Distribution

# %%
#### If you want to check whether feature is guassian or normal distributed
#### Q-Q plot
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
## create a normal distributed data
s=np.random.normal(0.5,0.2,1000)
plot_data(s)

# %%
plot_data(df['sepal_width'])

# %%
mu, sigma = 3., 1. # mean and standard deviation
sample = np.random.lognormal(mu, sigma, 100)

# %%
def plot_data_log(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(np.log(sample),dist='norm',plot=pylab)
    plt.show()

# %%
plot_data_log(sample)

# %% [markdown]
# ##Pearson and Sperman Rank Correlation

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
df.corr()
# Out:
# <ipython-input-79-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.pairplot(df)
